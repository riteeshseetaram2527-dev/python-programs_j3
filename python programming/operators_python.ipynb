# %% [markdown]
# # Operators in python
#
# ## python have six types of operators
# 1.arithematic operators
# 2.assignment operators
# 3.comparision operators
# 4.logical operators
# 5.membership operators
# 6.identity operators

# %%
#arithematic operators -,+,/,//,*,%
a=10
b=20
c=30
d=40
print(a+b)
print(b-d)
print(a*c)
print(b/a)
print(b//a)
print(d%b)
# Out:
# 30
# -20
# 300
# 2.0
# 2
# 0

# %%
a=26
b=28
c=29
d=30
print(a+b)
print(b-d)
print(a*c)
print(b/a)
print(b//a)
print(d%b)
# Out:
# 54
# -2
# 754
# 1.0769230769230769
# 1
# 2

# %%
#assignment operators -+=,-=,*=,/=,//=,%=
a=10
a=a+10
print(a)

# %%
a=10
a+=10
print(a)

# %%
a=25
a-=50
print(a)

# %%
a=26
a*=28
print(a)

# %%
a=27
a/=3
print(a)

# %%
a=23
a//=11
print(a)

# %%
a=100
a%=10
print(a)

# %%
#comparision operators -->,<,>=,<=,==,!=(return true or false)
a=10
b=20
c=30
d=40
print(a>b)
print(b<c)
print(b>=c)
print(a<=c)
print(b==c)
print(b!=d)
# Out:
# False
# True
# False
# True
# False
# True

# %%
#logical operators--and,or,not
# and-this operators checking all conditions are true result is true rest cases failed
# or-this operator check either one conditions true true then result rest cases failed
a=10
b=20
c=20
d=60
print(a>b and b==c)
print(a<b and c<d)
print(a>b or b==c)
print(a>b or b!=c)
print(not a>b or B!=c)
# Out:
# False
# True
# True
# False
# True

# %%
#membership operators--checking members are present in that squence or collection -in ,not in
name=["shiva","vikas","alok","divya"]
print("alok"in name)
print("chandra"in name)
print("Shiva" not in name)
print("vikas"in name)
# Out:
# True
# False
# True
# True

# %%
#identity operators-- memory identification of values -is,is not
a=10000
b=10000
print(id(a))
print(id(b))
print(a is b)
# Out:
# 1479397873968
# 1479397872592
# False

# %%
a=10
b=10
print(id(a))
print(id(b))
print(a is b)
# Out:
# 140725134980296
# 140725134980296
# True
